# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **My Problem Statement:** <font color='red'>**Which state(s) and learning field(s) should the Department of Education put more fundings in to make the country/students stay competitive overall ?**

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# # The datasets that I have chosen for the analysis are listed as follow:

# %% [markdown]
# ---
# **The default datasets:**
# * <font color='red'>[`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State</font>
# * <font color='red'>[`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State</font>
# * <font color='red'>[`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State</font>
# * <font color='red'>[`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major</font>

# %% [markdown]
# ### Outside Research

# %% [markdown]
# 1. <font color='blue'>enrollment-of-undergraduate-students-in-2-year-colleges-us-1990-2020.xlsx (from US Census Bureau: NCES © Statista 2022)</font>
#
# ![statistic_id421127_enrollment-of-undergraduate-students-in-2-year-colleges-us-1990-2020.png](attachment:statistic_id421127_enrollment-of-undergraduate-students-in-2-year-colleges-us-1990-2020.png)
#
#
# 2. <font color='blue'>united-states---birth-rate-1990-2020.xlsx (from US Department of Health and Human Services: NCES © Statista 1990-2020)</font>
#
# ![statistic_id195943_united-states---birth-rate-1990-2020.png](attachment:statistic_id195943_united-states---birth-rate-1990-2020.png)

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def return_mean(values):
    mean = 0
    for i in range(1, len(values) +1):
        mean += i/len(values)
    
    return print("Mean / Average is: " + str(mean))

return_mean([1, 2, 3, 4, 5])

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
import math

def return_sd(n_num):
    for i in range(len(n_num)):
        mean = sum(n_num) / len(n_num)   # mean
        var  = sum(pow(i-mean,2) for i in n_num) / len(n_num)  # variance
        std  = math.sqrt(var) # standard deviation
    return std

return_sd([1, 2, 3, 4, 5])

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def convert_to_decimal(string):
    return float(string.strip('%'))/100

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Import and Cleaning for SAT2019 Dataset

# %% [markdown]
# #### Display the data, print the first 5 rows of each dataframe to your Jupyter notebook

# %%
sat2019 = pd.read_csv('sat_2019.csv', index_col=[0])
sat2019.head(5)
# Out:
#            Participation Rate  EBRW  Math  Total
# State
# Alabama                    7%   583   560   1143
# Alaska                    41%   556   541   1097
# Arizona                   31%   569   565   1134
# Arkansas                   6%   582   559   1141
# California                63%   534   531   1065

# %% [markdown]
# #### Check for any obvious issues with the observations

# %%
sat2019.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
#### Checking in for the basic info (the no. of rows and columns)

# %%
sat2019.shape
# Out:
# (53, 4)

# %%
#### Display the data types of each feature

# %%
sat2019.dtypes
# Out:
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
#### Check if there are any missing values

# %%
sat2019.isna().sum()
# Out:
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
#### The minimum & maximum possible values for each test

# %%
print(sat2019.min()) #The lowest scores
print('\n')
print(sat2019.max()) #The highest scores
# Out:
# Participation Rate    100%
# EBRW                   483
# Math                   445
# Total                  935
# dtype: object
#
#
# Participation Rate       —
# EBRW                   636
# Math                   648
# Total                 1284
# dtype: object

# %%
# Find the problematic rows:  ' - ' in the Participation Rate

# %%
prob_columns = sat2019[sat2019['Participation Rate'].str.contains('—')]
prob_columns
# Out:
#                Participation Rate  EBRW  Math  Total
# State
# Puerto Rico                     —   483   462    944
# Virgin Islands                  —   490   445    935

# %%
## Remove those problematic rows

# %%
sat2019.drop(sat2019.loc[sat2019['Participation Rate']== '—'].index, inplace=True)

# %%
#### Renaming Columns: Column names should be all lowercase without any spaces

# %%
sat2019.columns = sat2019.columns.str.lower()
sat2019.columns
# Out:
# Index(['participation rate', 'ebrw', 'math', 'total'], dtype='object')

# %%
#### Remove the space in the column name + Renaming

# %%
sat2019.rename(columns={'participation rate': 'participation_2019'}, inplace=True)
sat2019.rename(columns={'ebrw': 'ebrw_2019'}, inplace=True)
sat2019.rename(columns={'math': 'math_2019'}, inplace=True)
sat2019.rename(columns={'total': 'total_2019'}, inplace=True)

# %%
sat2019.columns
# Out:
# Index(['participation_2019', 'ebrw_2019', 'math_2019', 'total_2019'], dtype='object')

# %%
### Changing the Participation Rate column from String into Float

# %%
sat2019['participation_2019'] = sat2019['participation_2019'].apply(convert_to_decimal)

# %%
#Save your cleaned as csv files.
#sat2019.to_csv('sat_2019.csv', index=False)

# %% [markdown]
# # Data import and Cleaning for SAT 2018 Dataset (The same procedures as above)

# %%
sat2018 = pd.read_csv('sat_2018.csv')
sat2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat2018.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
print(sat2018.min()) #The lowest scores
print('\n')
print(sat2018.max()) #The highest scores
# Out:
# State                                 Alabama
# Participation                             10%
# Evidence-Based Reading and Writing        480
# Math                                      480
# Total                                     977
# dtype: object
#
#
# State                                 Wyoming
# Participation                             99%
# Evidence-Based Reading and Writing        643
# Math                                      655
# Total                                    1298
# dtype: object

# %%
sat2018.shape
# Out:
# (51, 5)

# %%
sat2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat2018.isna().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat2018.columns= sat2018.columns.str.lower()
sat2018.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
sat2018.rename(columns={'evidence-based reading and writing': 'ebrw_2018'}, inplace=True)
sat2018.rename(columns={'participation': 'participation_2018'}, inplace=True)
sat2018.rename(columns={'ebrw': 'ebrw_2018'}, inplace=True)
sat2018.rename(columns={'math': 'math_2018'}, inplace=True)
sat2018.rename(columns={'total': 'total_2018'}, inplace=True)

# %%
sat2018['participation_2018'] = sat2018['participation_2018'].apply(convert_to_decimal)

# %%
sat2018['participation_2018']
# Out:
# 0     0.06
# 1     0.43
# 2     0.29
# 3     0.05
# 4     0.60
# 5     1.00
# 6     1.00
# 7     1.00
# 8     0.92
# 9     0.56
# 10    0.70
# 11    0.56
# 12    1.00
# 13    0.99
# 14    0.63
# 15    0.03
# 16    0.04
# 17    0.04
# 18    0.04
# 19    0.99
# 20    0.76
# 21    0.80
# 22    1.00
# 23    0.04
# 24    0.03
# 25    0.04
# 26    0.10
# 27    0.03
# 28    0.23
# 29    0.96
# 30    0.82
# 31    0.16
# 32    0.79
# 33    0.52
# 34    0.02
# 35    0.08
# 36    0.18
# 37    0.48
# 38    0.70
# 39    0.97
# 40    0.55
# 41    0.03
# 42    0.06
# 43    0.66
# 44    0.04
# 45    0.64
# 46    0.68
# 47    0.69
# 48    0.28
# 49    0.03
# 50    0.03
# Name: participation_2018, dtype: float64

# %%
#Save your cleaned as csv files.
#sat2018.to_csv('sat_2018.csv', index=False)

# %% [markdown]
# # Data import and Cleaning for SAT 2017 Dataset (The same procedures as above)

# %%
sat2017 = pd.read_csv('sat_2017.csv')
sat2017.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
print(sat2017.min())
print('\n')
print(sat2017.max())
# Out:
# State                                 Alabama
# Participation                             10%
# Evidence-Based Reading and Writing        482
# Math                                       52
# Total                                     950
# dtype: object
#
#
# State                                 Wyoming
# Participation                             96%
# Evidence-Based Reading and Writing        644
# Math                                      651
# Total                                    1295
# dtype: object

# %%
sat2017.shape
# Out:
# (51, 5)

# %%
sat2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat2017.isna().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat2017.columns= sat2017.columns.str.lower()

# %%
sat2017.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
sat2017.rename(columns={'participation': 'participation_2017'}, inplace=True)
sat2017.rename(columns={'evidence-based reading and writing': 'ebrw_2017'}, inplace=True)
sat2017.rename(columns={'math': 'math_2017'}, inplace=True)
sat2017.rename(columns={'total': 'total_2017'}, inplace=True)

# %%
sat2017['participation_2017'] = sat2017['participation_2017'].apply(convert_to_decimal)

# %%
#Save your cleaned as csv files.
#sat2017.to_csv('sat_2017.csv', index=False)

# %% [markdown]
# # Data Cleaning for Intended College Major SAT 2019

# %%
df = pd.read_csv("sat_2019_by_intended_college_major.csv")
df.head(38)
# Out:
#                                  IntendedCollegeMajor TestTakers Percent  \
# 0   Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                   Architecture and Related Services     28,988      2%
# 2          Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 3                  Biological and Biomedical Sciences    155,834      8%
# 4   Business, Management, Marketing, and Related S...    221,523     12%
# 5     Communication, Journalism, and Related Programs     36,332      2%
# 6   Computer and Information Sciences and Support ...     79,736      4%
# 7                        Construction Trades, General      2,500      0%
# 8                                           Education     71,882      4%
# 9                                         Engineering    194,127     11%
# 10               Engineering Technologies/Technicians     33,595      2%
# 11            English Language and Literature/Letters     16,233      1%
# ...

# %%
df.shape
# Out:
# (38, 6)

# %%
df.dtypes
# Out:
# IntendedCollegeMajor    object
# TestTakers              object
# Percent                 object
# Total                    int64
# ReadingWriting           int64
# Math                     int64
# dtype: object

# %%
df.isna().sum()
# Out:
# IntendedCollegeMajor    0
# TestTakers              0
# Percent                 0
# Total                   0
# ReadingWriting          0
# Math                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['IntendedCollegeMajor', 'TestTakers', 'Percent', 'Total',
#        'ReadingWriting', 'Math'],
#       dtype='object')

# %%
df.columns= df.columns.str.lower()

# %%
df.rename(columns={'IntendedCollegeMajor': 'intendedcollegemajor_2019'}, inplace=True)
df.rename(columns={'testtakers': 'testtakers_2019'}, inplace=True)
df.rename(columns={'total': 'total_score_2019'}, inplace=True)
df.rename(columns={'readingwriting': 'readingwriting_2019'}, inplace=True)
df.rename(columns={'math': 'math_score_2019'}, inplace=True)

# %%
#Getting rid of the ',' in the string column for testtakers

# %%
df['testtakers_2019'] = df['testtakers_2019'].str.replace(",","")

# %%
#Changing the data type from 'str' to 'int'

# %%
df['testtakers_2019'] = df['testtakers_2019'].astype(int)

# %%
#Changing the data type from 'str' to 'int'

# %%
df['percent'] = df['percent'].apply(convert_to_decimal)

# %% [markdown]
# # Data Cleaning for ACT 2019

# %%
act2019 = pd.read_csv('act_2019.csv')

# %%
act2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
act2019.columns= act2019.columns.str.lower()

# %%
act2019.rename(columns={'participation': 'act_participation_2019'}, inplace=True)

# %%
act2019['act_participation_2019'] = act2019['act_participation_2019'].apply(convert_to_decimal)

# %%
act2019.isna().sum()
# Out:
# state                     0
# act_participation_2019    0
# composite                 0
# dtype: int64

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# ## Data Dictionary
#
# | Column Name | Data Type | Description |
# | --- | --- | --- |
# | State_(2017-2019) | Object | 50 states across USA |
# | Participation_(2017-2019) | Float | The Participation rate Across 50 states  |
# | ebrw_2017-2019 | Integer | The SAT Evidence-Based Reading and Writing Score from 2017-2019 Across 50 states |
# | math_(2017-2019) | Integer | The SAT Math Score from 2017-2019 Across 50 states  |
# | total_(2017-2019) | Integer | The SAT Math Score from 2017-2019 Across 50 states |
# | intendedcollegemajor | Integer | The Names of the Intended College Major  |
# | testtakers_2019 | float64 | he Raw Number of People who have taken the SAT and delcared that particular Major  |
# | percent | float64 | The Percentage of people who have taken the SAT and delcared that particular Major  |
# | total_score_2019 | float64 | The Percentage of people who have taken the SAT and delcared that particular Major  |
# | readingwriting_2019 | Integer | The Average Score of Students on Reading and Writing 2019 SAT tests|
# | math_score_2019 | Integer |The Average Score of Students on 2019 Math SAT tests  |
# | act_participation_2019 | float64 | The Participation Rate on 2019 ACT tests|
# | composite | float64 |The Overall Score of ACT |

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Return the standard deviation for all columns in a datasets in a dictionary format
#Standard Deviation of all the columns for SAT2019
{column:return_sd(sat2019[column].values) for column in sat2019.columns if type(sat2019[column][0]) != type('')}
# Out:
# {'participation_2019': 0.3836584048685726,
#  'ebrw_2019': 45.792378682545134,
#  'math_2019': 50.78521461840036,
#  'total_2019': 96.24027185617864}

# %%
#Standard Deviation of all the columns for SAT2018
{column:return_sd(sat2018[column].values) for column in sat2018.columns if type(sat2018[column][0]) != type('')}
# Out:
# {'participation_2018': 0.3694661922353942,
#  'ebrw_2018': 47.03460978357609,
#  'math_2018': 47.30194550378352,
#  'total_2018': 93.22742384464433}

# %%
#Standard Deviation of all the columns for SAT2017
{column:return_sd(sat2017[column].values) for column in sat2017.columns if type(sat2017[column][0]) != type('')}
# Out:
# {'participation_2017': 0.3492907076664507,
#  'ebrw_2017': 45.21697020437866,
#  'math_2017': 84.07255521608297,
#  'total_2017': 91.58351056778743}

# %%
#Standard Deviation of all the columns for ACT2019
{column:return_sd(act2019[column].values) for column in act2019.columns if type(act2019[column][0]) != type('')}
# Out:
# {'act_participation_2019': 0.33857996180008104, 'composite': 2.154467630119044}

# %%
#Standard Deviation of all the columns for Intended_College_Major_SAT2019
{column:return_sd(df[column].values) for column in df.columns if type(df[column][0]) != type('')}
# Out:
# {'testtakers_2019': 71789.43289002257,
#  'percent': 0.03944560404747735,
#  'total_score_2019': 81.35392139482761,
#  'readingwriting_2019': 40.814567832679806,
#  'math_score_2019': 42.811705236572365}

# %% [markdown]
# # (Part 1) EDA for <font color='red'> 2017-2019 SAT Scores </font>

# %% [markdown]
# # The Basic Statistics for <font color='green'>SAT2019</font>  Across The US
# <font color='black'>---------------------------------------------------------------------------------------------------------------</font>
# ### The average SAT score is  <font color='red'>1113</font>
# ### The mean Math score is <font color='red'>552</font>
# ### The mean Evidence-based writing and reading score is<font color='red'> 560</font>
# ### The mean Participation Rate is <font color='red'>49%</font>

# %%
#Code:
sat2019.describe()
# Out:
#        participation_2019   ebrw_2019   math_2019   total_2019
# count           51.000000   51.000000   51.000000    51.000000
# mean             0.490588  560.803922  552.196078  1113.078431
# std              0.387476   46.248035   51.290553    97.197910
# min              0.020000  483.000000  460.000000   943.000000
# 25%              0.055000  527.500000  511.500000  1038.000000
# 50%              0.540000  550.000000  546.000000  1097.000000
# 75%              0.820000  612.000000  599.000000  1210.000000
# max              1.000000  636.000000  648.000000  1284.000000

# %% [markdown]
# # The Basic Statistics for <font color='green'>SAT2018</font> Across The US
# <font color='black'>---------------------------------------------------------------------------------------------------------------</font>
# ### The average SAT score is  <font color='red'>1120</font>
# ### The mean Math score is <font color='red'>556</font>
# ### The mean Evidence-based writing and reading score is<font color='red'> 563</font>
# ### The mean Participation Rate is <font color='red'>45%</font>

# %%
sat2018.describe()
# Out:
#        participation_2018   ebrw_2018   math_2018   total_2018
# count           51.000000   51.000000   51.000000    51.000000
# mean             0.457451  563.686275  556.235294  1120.019608
# std              0.373143   47.502627   47.772623    94.155083
# min              0.020000  480.000000  480.000000   977.000000
# 25%              0.045000  534.500000  522.500000  1057.500000
# 50%              0.520000  552.000000  544.000000  1098.000000
# 75%              0.775000  610.500000  593.500000  1204.000000
# max              1.000000  643.000000  655.000000  1298.000000

# %% [markdown]
# # The Basic Statistics for <font color='green'>SAT2017</font> Across The US
# <font color='black'>---------------------------------------------------------------------------------------------------------------</font>
# ### The average SAT score is  <font color='red'>1126</font>
# ### The mean Math score is <font color='red'>547</font>
# ### The mean Evidence-based writing and reading score is<font color='red'> 569</font>
# ### The mean Participation Rate is <font color='red'>39%</font>

# %%
sat2017.describe()
# Out:
#        participation_2017   ebrw_2017   math_2017   total_2017
# count           51.000000   51.000000   51.000000    51.000000
# mean             0.398039  569.117647  547.627451  1126.098039
# std              0.352766   45.666901   84.909119    92.494812
# min              0.020000  482.000000   52.000000   950.000000
# 25%              0.040000  533.500000  522.000000  1055.500000
# 50%              0.380000  559.000000  548.000000  1107.000000
# 75%              0.660000  613.000000  599.000000  1212.000000
# max              1.000000  644.000000  651.000000  1295.000000

# %% [markdown]
# # In-depth research of sub-test for SAT2019

# %% [markdown]
# ## For SAT 2019: Top 3 States of  <font color='green'> Average SAT score:</font> <font color='red'>Minnesota #1 , ~Wisconsin #2 and ~South Dakota #3 </font> (In chronological order)

# %%
sat2019.sort_values(['total_2019'], ascending = False).head(10)
# Out:
#               participation_2019  ebrw_2019  math_2019  total_2019
# State
# Minnesota                   0.04        636        648        1284
# Wisconsin                   0.03        635        648        1283
# South Dakota                0.03        633        635        1268
# North Dakota                0.02        627        636        1263
# Nebraska                    0.03        628        631        1260
# Iowa                        0.03        622        622        1244
# Kansas                      0.04        618        623        1241
# Wyoming                     0.03        623        615        1238
# Mississippi                 0.03        628        608        1237
# Missouri                    0.04        622        615        1236

# %% [markdown]
# ## For SAT 2019: The Lowest 3 States of  <font color='green'> Average SAT score:</font> <font color='red'>West Virginia #1 , ~Oklahoma #2 and ~Delaware	 #3 </font> (In chronological order)

# %%
sat2019.sort_values(['total_2019'], ascending = True).head(10)
# Out:
#                       participation_2019  ebrw_2019  math_2019  total_2019
# State
# West Virginia                       0.99        483        460         943
# Oklahoma                            0.22        490        472         963
# District of Columbia                0.94        495        480         975
# Delaware                            1.00        499        486         985
# Idaho                               1.00        505        488         993
# Rhode Island                        1.00        503        492         995
# Florida                             1.00        516        483         999
# Michigan                            1.00        507        496        1003
# Maine                               0.99        512        502        1013
# Illinois                            1.00        509        504        1013

# %% [markdown]
# ##  For SAT 2019: Top 3 States of <font color='green'>Average Evidence-based Reading and Writing score:</font> <font color='red'>Minnesota #1 , ~Wisconsin #2 and ~South Dakota #3 </font> (In chronological order)

# %%
sat2019.sort_values(['ebrw_2019'], ascending = False).head(10)
# Out:
#               participation_2019  ebrw_2019  math_2019  total_2019
# State
# Minnesota                   0.04        636        648        1284
# Wisconsin                   0.03        635        648        1283
# South Dakota                0.03        633        635        1268
# Nebraska                    0.03        628        631        1260
# Mississippi                 0.03        628        608        1237
# North Dakota                0.02        627        636        1263
# Wyoming                     0.03        623        615        1238
# Iowa                        0.03        622        622        1244
# Missouri                    0.04        622        615        1236
# Kentucky                    0.04        620        612        1232

# %% [markdown]
# ## For SAT 2019: The Lowest 3 States of  <font color='green'> Average Evidence-based reading and writing score:</font> <font color='red'>West Virginia #1 , ~Oklahoma #2 and ~Delaware	 #3 </font> (In chronological order)

# %%
sat2019.sort_values(['ebrw_2019'], ascending = True).head(10)
# Out:
#                       participation_2019  ebrw_2019  math_2019  total_2019
# State
# West Virginia                       0.99        483        460         943
# Oklahoma                            0.22        490        472         963
# District of Columbia                0.94        495        480         975
# Delaware                            1.00        499        486         985
# Rhode Island                        1.00        503        492         995
# Idaho                               1.00        505        488         993
# Michigan                            1.00        507        496        1003
# Illinois                            1.00        509        504        1013
# Maine                               0.99        512        502        1013
# Texas                               0.68        515        507        1022

# %% [markdown]
# ##  For SAT 2019: Top 3 States of <font color='green'>Average Math score:</font> <font color='red'>Wisconsin #1 , ~Minnesota #2 and ~North Dakota #3 </font> (In chronological order)

# %%
sat2019.sort_values(['math_2019'], ascending = False).head(10)
# Out:
#               participation_2019  ebrw_2019  math_2019  total_2019
# State
# Wisconsin                   0.03        635        648        1283
# Minnesota                   0.04        636        648        1284
# North Dakota                0.02        627        636        1263
# South Dakota                0.03        633        635        1268
# Nebraska                    0.03        628        631        1260
# Kansas                      0.04        618        623        1241
# Iowa                        0.03        622        622        1244
# Missouri                    0.04        622        615        1236
# Utah                        0.04        614        615        1230
# Wyoming                     0.03        623        615        1238

# %% [markdown]
# ## For SAT 2019: The Lowest 3 States of  <font color='green'> Average Math score:</font> <font color='red'>West Virginia #1 , ~Oklahoma #2 and ~Florida	 #3 </font> (In chronological order)

# %%
sat2019.sort_values(['math_2019'], ascending = True).head(10)
# Out:
#                       participation_2019  ebrw_2019  math_2019  total_2019
# State
# West Virginia                       0.99        483        460         943
# Oklahoma                            0.22        490        472         963
# District of Columbia                0.94        495        480         975
# Florida                             1.00        516        483         999
# Delaware                            1.00        499        486         985
# Idaho                               1.00        505        488         993
# Rhode Island                        1.00        503        492         995
# Michigan                            1.00        507        496        1003
# Maine                               0.99        512        502        1013
# South Carolina                      0.68        526        504        1030

# %% [markdown]
# ## For SAT 2019:  States that earn <font color='green'> 100% SAT Participation Rate:</font> <font color='red'>Rhode Island , Illinois, Michigan, Colorado, Connecticut, Delaware, Florida, Idaho </font>

# %%
sat2019.sort_values(['participation_2019'], ascending = False).head(20)
# Out:
#                       participation_2019  ebrw_2019  math_2019  total_2019
# State
# Rhode Island                        1.00        503        492         995
# Illinois                            1.00        509        504        1013
# Michigan                            1.00        507        496        1003
# Colorado                            1.00        518        506        1024
# Connecticut                         1.00        529        516        1046
# Delaware                            1.00        499        486         985
# Florida                             1.00        516        483         999
# Idaho                               1.00        505        488         993
# Maine                               0.99        512        502        1013
# West Virginia                       0.99        483        460         943
# New Hampshire                       0.95        533        526        1059
# ...

# %% [markdown]
# ## For SAT 2019: States of  <font color='green'> Lowest Participation Rate:</font> <font color='red'>North Dakota(#1), Wyoming(#2), South Dakota(#2), Nebraska(#2), Wisconsin(#2), Mississippi(#2), Iowa(#2), Utah (#3), Minnesota(#3) </font> (in chronological order)

# %%
sat2019.sort_values(['participation_2019'], ascending = True).head(20)
# Out:
#               participation_2019  ebrw_2019  math_2019  total_2019
# State
# North Dakota                0.02        627        636        1263
# Wyoming                     0.03        623        615        1238
# South Dakota                0.03        633        635        1268
# Nebraska                    0.03        628        631        1260
# Wisconsin                   0.03        635        648        1283
# Mississippi                 0.03        628        608        1237
# Iowa                        0.03        622        622        1244
# Utah                        0.04        614        615        1230
# Minnesota                   0.04        636        648        1284
# Kentucky                    0.04        620        612        1232
# Kansas                      0.04        618        623        1241
# Missouri                    0.04        622        615        1236
# Louisiana                   0.05        610        591        1200
# ...

# %% [markdown]
# # (Part 2) EDA for  <font color='red'>Intended College Major</font>

# %% [markdown]
# ## The total number of test takers for SAT2019 is  <font color='red'>1,838,991</font>

# %%
df['testtakers_2019'].sum()
# Out:
# 1838991

# %%
df.describe()
# Out:
#        testtakers_2019    percent  total_score_2019  readingwriting_2019  \
# count        38.000000  38.000000         38.000000            38.000000
# mean      48394.500000   0.025789       1058.500000           535.500000
# std       72753.092558   0.039975         82.445969            41.362439
# min         283.000000   0.000000        916.000000           458.000000
# 25%        6611.000000   0.000000        988.250000           501.250000
# 50%       16370.500000   0.010000       1066.500000           537.000000
# 75%       60215.750000   0.035000       1115.500000           569.750000
# max      331026.000000   0.180000       1242.000000           597.000000
#
#        math_score_2019
# count        38.000000
# mean        523.000000
# std          43.386385
# min         456.000000
# 25%         486.500000
# 50%         527.000000
# 75%         542.250000
# max         646.000000

# %% [markdown]
# # <font color='green'>Top 3 Popular Intended College Majors for SAT2019</font> - <font color='red'>#1 Health Professions and related Clinical Sciences <font color='orange'>(18%)</font>, #2 Business, Management, Marketing <font color='orange'>(12%)</font> #3 Engineering <font color='orange'>(11%)</font>

# %%
df.sort_values(['testtakers_2019'], ascending = False).head(10)
# Out:
#                                  intendedcollegemajor  testtakers_2019  \
# 14   Health Professions and related Clinical Sciences           331026
# 4   Business, Management, Marketing, and Related S...           221523
# 9                                         Engineering           194127
# 3                  Biological and Biomedical Sciences           155834
# 35                Visual and Performing Arts, General           130642
# 37                                          Undecided           126939
# 6   Computer and Information Sciences and Support ...            79736
# 29                                Psychology, General            75626
# 8                                           Education            71882
# 31                   Security and Protective Services            68177
#
#     percent  total_score_2019  readingwriting_2019  math_score_2019
# 14     0.18              1048                  529              518
# ...

# %% [markdown]
# # <font color='green'>Top 3 Most Unpopular Intended College Majors for SAT2019</font> - <font color='red'>#1 Library Science/Librarianship <font color='orange'>(283)</font>, #2 Precision Production <font color='orange'>(319)</font>, #3 Transportation and Materials Moving <font color='orange'>(1105) </font>

# %%
df.sort_values(['testtakers_2019'], ascending = True).head(10)
# Out:
#                             intendedcollegemajor  testtakers_2019  percent  \
# 18                 Library Science/Librarianship              283      0.0
# 28                          Precision Production              319      0.0
# 34           Transportation and Materials Moving             1105      0.0
# 33              Theology and Religious Vocations             1991      0.0
# 7                   Construction Trades, General             2500      0.0
# 2     Area, Ethnic, Cultural, and Gender Studies             2629      0.0
# 22               Multi/Interdisciplinary Studies             2979      0.0
# 26              Philosophy and Religious Studies             3381      0.0
# 12   Family and Consumer Sciences/Human Sciences             6469      0.0
# 20  Mechanic and Repair Technologies/Technicians             6592      0.0
#
#     total_score_2019  readingwriting_2019  math_score_2019
# 18              1105                  577              527
# ...

# %% [markdown]
# # (Part 3) EDA for <font color='red'> 2019 ACT Scores </font>

# %% [markdown]
# # <font color='red'>Alabama, Oklahoma, Ohio, North Carolina, Tennessee, Nevada, Nebraska, Montana, Wyoming and Mississippi </font> all have <font color='green'>100% ACT participation rate </font>

# %%
act2019.sort_values(['act_participation_2019'], ascending = True).head(10)
# Out:
#             state  act_participation_2019  composite
# 19          Maine                    0.06       24.3
# 39   Rhode Island                    0.12       24.7
# 7        Delaware                    0.13       24.1
# 29  New Hampshire                    0.14       25.0
# 38   Pennsylvania                    0.17       23.6
# 22       Michigan                    0.19       24.4
# 45        Vermont                    0.20       24.1
# 21  Massachusetts                    0.21       25.5
# 46       Virginia                    0.21       24.0
# 6     Connecticut                    0.22       25.5

# %% [markdown]
# # <font color='red'>New Mexico, Iowa, Kansas, Arizona, South Dakota, South Carolina <font color='green'> >80% ACT participation rate </font>

# %%
act2019.sort_values(['act_participation_2019'], ascending = False).head(10)
# Out:
#              state  act_participation_2019  composite
# 0          Alabama                     1.0       18.9
# 17        Kentucky                     1.0       19.8
# 50         Wyoming                     1.0       19.8
# 49       Wisconsin                     1.0       20.3
# 44            Utah                     1.0       20.3
# 42       Tennessee                     1.0       19.4
# 36        Oklahoma                     1.0       18.9
# 35            Ohio                     1.0       20.0
# 33  North Carolina                     1.0       19.0
# 28          Nevada                     1.0       17.9

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# # Heatmap Analysis for SAT 2017-2019

# %% [markdown]
# ## <font color='green'>For SAT 2019</font>, <font color='red'>there is negative correlation between the participation rate and the rest of the 3 sub-tests</font>, which means that the participation rate does not share a strong correlation to the sub-test score, <font color='purple'> while other sub-tests share positive correlations among each other </font>.

# %%
plt.figure(figsize=(16, 5))
sns.heatmap(sat2019.corr(), annot=True)
plt.tight_layout()
plt.title('Correlation of Different Sub-test, Participation Rate and Total Score in SAT2018', fontsize=15)
plt.show()

# %% [markdown]
# ## <font color='green'>For SAT 2018</font>, there is still a negative correlation between the participation rate and the rest of the 3 sub-tests,  <font color='red'> it is more or less the same,  <font color='purple'> except for a very slight decrease in the correlation between Math and Evidence-based reading and writing scores.

# %%
plt.figure(figsize=(16, 5))
sns.heatmap(sat2018.corr(), annot=True)
plt.tight_layout()
plt.title('Correlation of Different Sub-test, Participation Rate and Total Score in SAT2018', fontsize=15)
plt.show()

# %% [markdown]
# ## <font color='green'>Interestingly, for SAT 2017</font>, <font color='red'>there is a stronger correlation between the participation rate and the Math test,  <font color='purple'> while there are less correlations among the sub-tests.

# %%
plt.figure(figsize=(16, 5))
sns.heatmap(sat2017.corr(), annot=True)
plt.tight_layout()
plt.title('Correlation of Different Sub-test, Participation Rate and Total Score in SAT2017', fontsize=15)
plt.show()

# %% [markdown]
# #  <font color='red'>A similar trend can be spotted in ACT2019</font> -  <font color='purple'>negative correlation between the participation rate and average scores</font>.

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(act2019.corr(), annot=True)
plt.tight_layout()
plt.title('Correlation of Participation Rate and Composite in ACT2019', fontsize=15)
plt.show()

# %% [markdown]
# ## The box plots below show:
# ### (1) a <font color='red'>slight drop</font> in the average Math SAT score <font color='green'>from 2018 to 2019</font>
# ### (2) a <font color='red'>declining</font>  average SAT Evidence-baaed writing and reading score from<font color='green'> 2017-2019</font>

# %%
ax = plt.subplots(figsize=(4,4))
plt.title('2017 SAT EBRW and Math Scores',fontsize=20)
plt.ylabel('Score',fontsize=12)
plt.ylim(450, 675)
sns.boxplot(data=sat2017[['ebrw_2017','math_2017']],width=0.4);

ax = plt.subplots(figsize=(4,4))
plt.title('2018 SAT EBRW and Math Scores',fontsize=20)
plt.ylabel('Score',fontsize=12)
plt.ylim(450, 675)
sns.boxplot(data=sat2018[['ebrw_2018','math_2018']],width=0.4)

ax = plt.subplots(figsize=(4,4))
plt.title('2019 SAT EBRW and Math Scores',fontsize=20)
plt.ylabel('Score',fontsize=12)
plt.ylim(450, 675)
sns.boxplot(data=sat2019[['ebrw_2019','math_2019']],width=0.4);

# %% [markdown]
# ## The Green box plots below shows:
# ### (1) a <font color='red'>subtle drop</font>  in average overall SAT score <font color='green'>from 2018 to 2019</font>

# %%
sns.boxplot(x=sat2019['total_2019'], data=sat2019 ,palette='rainbow')
plt.xlabel('Average Overall Score',fontsize=12)
plt.title('Average Total 2019 SAT Score',fontsize=20);

# %%
sns.boxplot(x=sat2018['total_2018'], data=sat2018 ,palette='rainbow')
plt.xlabel('Average Overall Score',fontsize=12)
plt.title('Average Total 2018 SAT Score',fontsize=20);

# %%
sns.boxplot(x=sat2017['total_2017'], data=sat2019 ,palette='rainbow')
plt.xlabel('Average Overall Score',fontsize=12)
plt.title('Average Total 2017 SAT Score',fontsize=20);

# %% [markdown]
# ## The blue box plots below shows:
# ### (1) a <font color='red'> distribution of average overall ACT 2019 score </font>

# %%
sns.boxplot(x=act2019['composite'], data=sat2019)
plt.xlabel('Average Overall Score',fontsize=12)
plt.title('Average Total 2019 ACT Score',fontsize=20);

# %% [markdown]
# ## The bar chart below shows  <font color='green'>an overall distribution</font> where <font color='red'>where states with a lower SAT average scores related to a higher participation rate in SAT2019</font>

# %%
sns.set(style="whitegrid")
  
ax = sns.scatterplot(x='total_2019', y='participation_2019', data=sat2019)

ax.set(xlabel ='The Overall Average SAT Score', ylabel ='The Participation Rate')

plt.title('The Relationship between Average Total Score and the Participation Rate for SAT 2019', fontsize=19)

plt.show()
#sns.set(rc = {'figure.figsize':(30,30)})
#plt.savefig('plot.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## The bar chart below shows  <font color='green'>an overall distribution</font> where <font color='red'>where states with a lower ACT average scores related to a higher participation rate in ACT2019</font>

# %%
sns.set(style="whitegrid")
  
ax = sns.scatterplot(x='composite', y='act_participation_2019', data=act2019)

ax.set(xlabel ='The Overall Average ACT Score', ylabel ='The Participation Rate')

plt.title('The Relationship between Average Total Score and the Participation Rate for ACT 2019', fontsize=19)

#sns.set(rc = {'figure.figsize':(30,30)})
plt.show()

# %% [markdown]
# ## The Overall Distribution of Different <font color='green'>2019 SAT Participation rate</font> <font color='red'>Across 50 States</font>

# %%
#Drop District of Columbia
sat2019.drop(['District of Columbia'], inplace = True)

# %%
sat2019['participation_2019'].sort_values().head(50).plot.bar(figsize=(20,5))
plt.ylabel('Participation Rate')
plt.xlabel('States')
plt.title('2019 SAT Participation Rate');

# %% [markdown]
# ## The Overall Distribution of Different <font color='green'>2019 ACT Participation rate</font> <font color='red'>Across 50 States</font>

# %%
#Drop District of Columbia
#act2019.drop(['District of Columbia'], inplace = True)

# %%
# run this code whenever the states' names are not appearing 
act2019.set_index('state', inplace = True)

# %%
act2019['act_participation_2019'].sort_values().head(50).plot.bar(figsize=(20,5))
plt.ylabel('Participation Rate')
plt.xlabel('States')
plt.title('2019 ACT Participation Rate');

# %% [markdown]
# ## For SAT 2019: Top 10 States of  <font color='green'> Average SAT scores:</font> <font color='red'> (In chronological order from left to right)

# %%
sat2019.sort_values(by='total_2019',ascending=False).head(10).plot.barh(figsize=(20,10), legend=True)
plt.ylabel('Top 10 States')
plt.xlabel('Scores')
plt.title('Distribution of 2019 SAT scores');

# %%
#df['testtakers_2019'].value_counts()
#Make the data as the format of the plot first!
sns.barplot(data = df.sort_values(['testtakers_2019'], ascending = False).head(5), y = 'intendedcollegemajor', 
            x = 'testtakers_2019');
plt.ylabel('The Intended College Major')
plt.xlabel('The Number of Students')
plt.title('The Top 5 Most Popular Intended College Major for SAT2019');

# %%
sns.barplot(data = df.sort_values(['testtakers_2019'], ascending = True).head(5), y = 'intendedcollegemajor', 
            x = 'testtakers_2019');
plt.ylabel('The Intended College Major')
plt.xlabel('The Number of Students')
plt.title('The Top 5 Least Popular Intended College Major for SAT2019');

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# It is clear that:
# <br> **(1) The higher the scores that the states have, the lower participation rates that they tend to have. Therefore, the scores might not be a best representation of the students' strength so far.**
#
# **(2) More attention has to be given to South Dakota, as it has a low participation rate in both ACT and SAT.**
#
# **(3) Medical, business and engineering programs are the most popular learning fields.**
#
# **(4) Librarianship, precision production and transportation are the least popular learning fields.**

# %% [markdown]
# **Conclusions and Recommendations:**
# My suggestions are **3-folded**:
#
# Suggestions for **Schools**:
# 1. To improve states with lower test performamces: Offer free, compulsory SAT/ACT Preparatory Test Day:
# By providing free test days, students can get familiarized with both SAT/ACT and see which test suits them the most, and better prepared for the test.
# According to research from the College Board, 63% of students increase their SAT test score when taking the exam twice.
#
# 2. Mandatory SAT/ACT Graduation Policies: Improve Participation Rate:
# Extend the mandate to not only 11 states, but all other states (especially South Dakota), where students will require to complete SAT/ACT to graduate high school.
#
#
# 3. Empower students, who are NOT interested in pursuing traditional college path, with college alternatives:
# Provide vocational training schools, skill-based study paths, rather than restricting students to merely go for academia route.
#
# Suggestions for **Colleges**:
# 1. Adopt holistic college admission strategy
# Apart from solely considering SAT/ACT, they should look at the candidate as a whole, including their
# <br>a. High school grade point average (GPA)
# <br>b. High school course load and curriculum
# <br>c. Participation in extracurricular activities
# <br>d. Recommendation letters (Unquantified qualities)
# <br>e. Application essays and personal statements (Unquantified qualities)
#
# Suggestions for **Future Curriculum Development**:
# 1. Revamp the unpopular programs such as librarianship, precision production and transportation with AI elements.
# 2. Add more fundings to enhance the current medical, business and engineering programs and import high quality teaching with an additional focus on AI.
